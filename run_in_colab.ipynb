# %%
# =============================
# 1️⃣ Install All Dependencies (Stable Versions)
# =============================

# !pip install --upgrade setuptools wheel

# Core pipeline dependencies (same as your working notebook)
# !pip install facenet-pytorch==2.5.3
# !pip install opencv-python-headless
# !pip install mtcnn==0.1.1
# !pip install pandas>=2.1.2
# !pip install scikit-learn matplotlib numpy Pillow

# Streamlit + Ngrok for UI
# !pip install streamlit pyngrok

# %%
from google.colab import drive
import os

# Mount Drive
drive.mount('/content/drive')

# Path to your project in Drive (change this if needed)
PROJECT_PATH = "/content/drive/MyDrive/Project alt version"

# Change working directory to your project folder
os.chdir(PROJECT_PATH)
print("✅ Current working directory:", os.getcwd())

# (Optional) List files to confirm app.py and src/ exist
# !ls -R | head -n 40
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Current working directory: /content/drive/MyDrive/Project alt version
# .:
# app.py
# models
# requirements.txt
# run_in_colab.ipynb
# src
# temp_faces
# temp_upload
#
# ./models:
# facenet_lfw_best_state.pth
#
# ./src:
# clustering.py
# Copy of visualization.py
# data_augmentation.py
# embedding.py
# evaluation.py
# face_detection.py
# __init__.py
# __pycache__
# utils.py
# visualization.py
#
# ./src/__pycache__:
# clustering.cpython-312.pyc
# data_augmentation.cpython-312.pyc
# embedding.cpython-312.pyc
# evaluation.cpython-312.pyc
# face_detection.cpython-312.pyc
# __init__.cpython-312.pyc
# utils.cpython-312.pyc
# visualization.cpython-312.pyc
#
# ./temp_faces:
#
# ./temp_upload:

# %%
# 2️⃣ (Optional) Authenticate Ngrok to avoid timeout (use your free ngrok token if you have one)
# Sign up at https://dashboard.ngrok.com/get-started/your-authtoken
# Uncomment the line below and paste your token after the '='
# !ngrok authtoken 2Eg3sumWysUcQnGk1hv7EUu42Zm_6yF8WpgoGtbD6vY8yDhhe
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# 3️⃣ Run Streamlit app via ngrok
import os
from pyngrok import ngrok

# %%
# Stop any previous tunnels
ngrok.kill()

# %%
# Start Streamlit tunnel
port = 8501
public_url = ngrok.connect(port).public_url
print(f"🌐 Streamlit App URL: {public_url}")
# Out:
# 🌐 Streamlit App URL: https://e19664620bd8.ngrok-free.app

# %%
# !streamlit run app.py --server.port 8501 --server.enableCORS false --server.enableXsrfProtection false
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.142.144.68:8501
# WARNING:pyngrok.process.ngrok:t=2025-10-31T17:34:08+0000 lvl=warn msg="failed to check for update" obj=updater err="Post \"https://update.equinox.io/check\": context deadline exceeded"
# /usr/local/lib/python3.12/dist-packages/mtcnn/mtcnn.py:34: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 2025-10-31 17:35:38.537839: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...
